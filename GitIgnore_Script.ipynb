# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\bsund\\Udacity Projects\\SB_SelfDrivingCar_ND'

# %%
# %%writefile .gitignore
# # Datasets (never commit)
# data/
# __oi_bootstrap__/
# openimages_csv/
#
# # Python
# __pycache__/
# *.pyc
#
# # Jupyter
# .ipynb_checkpoints/
#
# # OS junk
# .DS_Store
# Thumbs.db
# Out:
# Writing .gitignore

# %%
# Header 1 (Run this to See Hidden Files)

# %%
import os
os.listdir(".")
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'data',
#  'GitIgnore_Script.ipynb',
#  'notebooks',
#  'openimages_csv',
#  'README.md',
#  'scripts',
#  'src',
#  '__oi_bootstrap__']
